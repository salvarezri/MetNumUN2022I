# %% [markdown]
# # **Laboratorio 03**
# ### **Metodos Numericos - 2022 - I**
# Santiago Alvarez Ricardo
#
# LinkedIn: https://www.linkedin.com/in/santiago-alvarez-ricardo-b48138238/

# %% [markdown]
# **Python 101 for Data Science**:
# ![Python 101 for Data Science.png](data:image/png;base64,...)

# %% [markdown]
# **Data Analysis with Python**
# ![](data:image/png;base64,...)
